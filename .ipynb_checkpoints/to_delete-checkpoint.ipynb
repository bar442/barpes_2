# %%
# %gui qt5
import sys
sys.path.append(r"C:\repos\barpes_2")
from typing import *
from model import *
from view import *


# import sys
# !{sys.executable} -m pip install PyQt5

# %%
# Out:
# ...
#   Using cached PyQt5-5.15.11-cp38-abi3-win_amd64.whl.metadata (2.1 kB)
# ...
#   Using cached pyqt5_sip-12.17.2-cp313-cp313-win_amd64.whl.metadata (516 bytes)
# ...
#   Using cached PyQt5_Qt5-5.15.2-py3-none-win_amd64.whl.metadata (552 bytes)
# Using cached PyQt5-5.15.11-cp38-abi3-win_amd64.whl (6.9 MB)
# Using cached PyQt5_Qt5-5.15.2-py3-none-win_amd64.whl (50.1 MB)
# Using cached pyqt5_sip-12.17.2-cp313-cp313-win_amd64.whl (58 kB)
# ...
# [notice] A new release of pip is available: 25.0.1 -> 25.3
# [notice] To update, run: C:\Users\bar\AppData\Local\Programs\Python\Python313\python.exe -m pip install --upgrade pip
