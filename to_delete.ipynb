# %%
# %gui qt5
import sys
sys.path.append(r"C:\repos\barpes_2")
from typing import *
from model import *
from view import *


# import sys
# !{sys.executable} -m pip install PyQt5

# %%
sss= DataViewer1D()
aaa=show_widget(sss,"fsdfs")

# %%
sss= DataViewer1D()
aaa=show_widget(sss,"ddddddd")

# %%
brp_widg = BarpesGraphicsLayoutWidget()
brp_plot = brp_widg.addBarpesPlot(1,1)
show_widget(brp_widg,"fsdfs")
